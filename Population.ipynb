# %%
# Import Dependencies
import pandas as pd

# %%
# Import our input dataset
population_df = pd.read_csv('Resources/API_SP.POP.TOTL_DS2_en_csv_v2_3469297.csv')
population_df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965  ...         2011         2012         2013         2014  \
# ...

# %%
# Drop Indicator Name and Code
population_df = population_df.drop(columns=['Indicator Name', 'Indicator Code'])

# %%
list(population_df)
# Out:
# ['Country Name',
#  'Country Code',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020']

# %%
# Pivot Population Dataframe
population_pivot_df = population_df.melt(id_vars = ['Country Name', 'Country Code'], var_name = 'Year', value_name = 'Population', value_vars = [
 '1960',
 '1961',
 '1962',
 '1963',
 '1964',
 '1965',
 '1966',
 '1967',
 '1968',
 '1969',
 '1970',
 '1971',
 '1972',
 '1973',
 '1974',
 '1975',
 '1976',
 '1977',
 '1978',
 '1979',
 '1980',
 '1981',
 '1982',
 '1983',
 '1984',
 '1985',
 '1986',
 '1987',
 '1988',
 '1989',
 '1990',
 '1991',
 '1992',
 '1993',
 '1994',
 '1995',
 '1996',
 '1997',
 '1998',
 '1999',
 '2000',
 '2001',
 '2002',
 '2003',
 '2004',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016',
 '2017',
 '2018',
 '2019',
 '2020'])
population_pivot_df
# Out:
#                       Country Name Country Code  Year   Population
# 0                            Aruba          ABW  1960      54208.0
# 1      Africa Eastern and Southern          AFE  1960  130836765.0
# 2                      Afghanistan          AFG  1960    8996967.0
# 3       Africa Western and Central          AFW  1960   96396419.0
# 4                           Angola          AGO  1960    5454938.0
# ...                            ...          ...   ...          ...
# 16221                       Kosovo          XKX  2020    1775378.0
# 16222                  Yemen, Rep.          YEM  2020   29825968.0
# 16223                 South Africa          ZAF  2020   59308690.0
# 16224                       Zambia          ZMB  2020   18383956.0
# 16225                     Zimbabwe          ZWE  2020   14862927.0
#
# [16226 rows x 4 columns]

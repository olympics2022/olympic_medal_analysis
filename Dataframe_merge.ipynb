# %%
# Import Dependencies
import pandas as pd

# %%
# Import datasets
athlete_counts_df = pd.read_csv('CSV_In_Progress/competitor_count.csv')
population_df = pd.read_csv('Clean_Country_population.csv')
gdp_df = pd.read_csv('CSV_In_Progress/clean_gdp_final.csv')
medal_count_df = pd.read_csv('Olympic_Medal_Counts.csv')

# %%
# CLean athlete counts df
athlete_counts_df = athlete_counts_df.rename(columns={'CompetitorID' : 'athlete_count'})
athlete_counts_df.head()
# Out:
#    Unnamed: 0  NOC  Year  Season  Host  athlete_count
# 0           0  AFG  1936  Summer     0              4
# 1           1  AFG  1948  Summer     0              2
# 2           2  AFG  1956  Summer     0              1
# 3           3  AFG  1960  Summer     0             13
# 4           4  AFG  1964  Summer     0              8

# %%
# Dataframe with Olympic years after 1959
olympic_years_df = athlete_counts_df[['Year', 'Season']]
olympic_years_df = olympic_years_df.drop_duplicates()
olympic_years_df = olympic_years_df[olympic_years_df['Year'] > 1959]
olympic_years_df
# Out:
#      Year  Season
# 3    1960  Summer
# 4    1964  Summer
# 5    1968  Summer
# 6    1972  Summer
# 7    1980  Summer
# 8    1988  Summer
# 9    1996  Summer
# 10   2004  Summer
# 11   2008  Summer
# 12   2012  Summer
# 13   2016  Summer
# 19   1976  Summer
# 20   1984  Summer
# 22   1988  Winter
# 23   1992  Summer
# 24   1992  Winter
# 26   2000  Summer
# 34   2006  Winter
# 36   2010  Winter
# 38   2014  Winter
# 57   1976  Winter
# 59   1980  Winter
# 61   1984  Winter
# 66   1994  Winter
# 68   1998  Winter
# 70   2002  Winter
# 113  1960  Winter
# 115  1964  Winter
# 117  1968  Winter
# 119  1972  Winter

# %%
# Clean population dataframe
population_df = population_df.drop(['Primary Key', 'Country Name'], axis=1)
population_df.head()
# Out:
#   Country Code  Year  Population
# 0          ARU  1960       54208
# 1          AFG  1960     8996967
# 2          ANG  1960     5454938
# 3          ALB  1960     1608800
# 4          AND  1960       13410

# %%
# Clean gdp dataset
gdp_df = gdp_df.drop(['Primary Key', 'Entity'], axis=1)
gdp_df.head()
# Out:
#   Code  Year  GDP per capita
# 0  AFG  1950          1156.0
# 1  AFG  1951          1170.0
# 2  AFG  1952          1189.0
# 3  AFG  1953          1240.0
# 4  AFG  1954          1245.0

# %%
# Clean Medal Count dataset
medal_count_df = medal_count_df.drop(['Primary Key', 'Nation'], axis=1)
medal_count_df.head()
# Out:
#    Year  Season NOC Code  Gold  Silver  Bronze  Total
# 0  2008  Summer      AFG     0       0       1      1
# 1  2012  Summer      AFG     0       0       1      1
# 2  1984  Summer      ALG     0       0       2      2
# 3  1992  Summer      ALG     1       0       1      2
# 4  1996  Summer      ALG     2       0       1      3

# %%
# Merge athlete counts and population dataframes
count_and_pop_df = pd.merge(athlete_counts_df, population_df, how='left', left_on=['NOC', 'Year'], right_on=['Country Code', 'Year'])
count_and_pop_df = count_and_pop_df.drop(['Country Code'], axis=1)
count_and_pop_df
# Out:
#       Unnamed: 0  NOC  Year  Season  Host  athlete_count  Population
# 0              0  AFG  1936  Summer     0              4         NaN
# 1              1  AFG  1948  Summer     0              2         NaN
# 2              2  AFG  1956  Summer     0              1         NaN
# 3              3  AFG  1960  Summer     0             13   8996967.0
# 4              4  AFG  1964  Summer     0              8   9744772.0
# ...          ...  ...   ...     ...   ...            ...         ...
# 3868        3832  ZIM  2004  Summer     0             13  12019911.0
# 3869        3833  ZIM  2008  Summer     0             16  12379553.0
# 3870        3834  ZIM  2012  Summer     0              9  13115149.0
# 3871        3835  ZIM  2014  Winter     0              2  13586710.0
# 3872        3836  ZIM  2016  Summer     0             15  14030338.0
#
# [3873 rows x 7 columns]

# %%
# Merge count_and_pop_df with gdp
count_and_gdp_df = pd.merge(count_and_pop_df, gdp_df, how='left', left_on=['NOC', 'Year'], right_on=['Code', 'Year'])
count_and_gdp_df = count_and_gdp_df.drop(['Code'], axis=1)
count_and_gdp_df
# Out:
#       Unnamed: 0  NOC  Year  Season  Host  athlete_count  Population  \
# 0              0  AFG  1936  Summer     0              4         NaN
# 1              1  AFG  1948  Summer     0              2         NaN
# 2              2  AFG  1956  Summer     0              1         NaN
# 3              3  AFG  1960  Summer     0             13   8996967.0
# 4              4  AFG  1964  Summer     0              8   9744772.0
# ...          ...  ...   ...     ...   ...            ...         ...
# 3868        3832  ZIM  2004  Summer     0             13  12019911.0
# 3869        3833  ZIM  2008  Summer     0             16  12379553.0
# 3870        3834  ZIM  2012  Summer     0              9  13115149.0
# 3871        3835  ZIM  2014  Winter     0              2  13586710.0
# 3872        3836  ZIM  2016  Summer     0             15  14030338.0
#
#       GDP per capita
# 0                NaN
# 1                NaN
# 2            1278.00
# 3            1326.00
# 4            1291.00
# ...              ...
# 3868         1604.50
# 3869         1197.53
# 3870         1604.00
# 3871         1594.00
# 3872         1534.00
#
# [3873 rows x 8 columns]

# %%
# reset dataframe with olympic years
count_and_gdp_year_df = pd.merge(olympic_years_df, count_and_gdp_df, how="left", on="Year")
count_and_gdp_year_df
# Out:
#       Year Season_x  Unnamed: 0  NOC Season_y  Host  athlete_count  \
# 0     1960   Summer           3  AFG   Summer     0             13
# 1     1960   Summer          15  AHO   Summer     0              5
# 2     1960   Summer         112  ARG   Summer     0             78
# 3     1960   Summer         113  ARG   Winter     0             14
# 4     1960   Summer         186  AUS   Summer     0            201
# ...    ...      ...         ...  ...      ...   ...            ...
# 4593  1972   Winter        3730  VEN   Summer     0             27
# 4594  1972   Winter        3768  VNM   Summer     0              2
# 4595  1972   Winter        3799  YUG   Summer     0            162
# 4596  1972   Winter        3800  YUG   Winter     0             12
# 4597  1972   Winter        3812  ZAM   Summer     0             12
#
#       Population  GDP per capita
# 0      8996967.0          1326.0
# 1            NaN             NaN
# 2     20481781.0          8861.0
# 3     20481781.0          8861.0
# 4     10276477.0         14013.0
# ...          ...             ...
# 4593  12097696.0         15135.0
# 4594         NaN             NaN
# 4595         NaN             NaN
# 4596         NaN             NaN
# 4597   4466170.0          1761.0
#
# [4598 rows x 9 columns]

# %%
# Generate list of years with the olympics
olympic_years = athlete_counts_df['Year'].to_list()
olympic_year_list = []
[olympic_year_list.append(x) for x in olympic_years if x not in olympic_year_list]
olympic_year_list
# Out:
# [1936,
#  1948,
#  1956,
#  1960,
#  1964,
#  1968,
#  1972,
#  1980,
#  1988,
#  1996,
#  2004,
#  2008,
#  2012,
#  2016,
#  1952,
#  1976,
#  1984,
#  1992,
#  2000,
#  2006,
#  2010,
#  2014,
#  1994,
#  1998,
#  2002,
#  1908,
#  1912,
#  1900,
#  1920,
#  1924,
#  1928,
#  1932,
#  1896,
#  1904,
#  1906]

# %%
# Remove years without the olympics and drop NaN NOC and Country Code
count_and_gdp_filter_df = count_and_gdp_df[count_and_gdp_df['Year'].isin(olympic_year_list)]
count_and_gdp_filter_df
# Out:
#       Unnamed: 0  NOC  Year  Season  Host  athlete_count  Population  \
# 0              0  AFG  1936  Summer     0              4         NaN
# 1              1  AFG  1948  Summer     0              2         NaN
# 2              2  AFG  1956  Summer     0              1         NaN
# 3              3  AFG  1960  Summer     0             13   8996967.0
# 4              4  AFG  1964  Summer     0              8   9744772.0
# ...          ...  ...   ...     ...   ...            ...         ...
# 3868        3832  ZIM  2004  Summer     0             13  12019911.0
# 3869        3833  ZIM  2008  Summer     0             16  12379553.0
# 3870        3834  ZIM  2012  Summer     0              9  13115149.0
# 3871        3835  ZIM  2014  Winter     0              2  13586710.0
# 3872        3836  ZIM  2016  Summer     0             15  14030338.0
#
#       GDP per capita
# 0                NaN
# 1                NaN
# 2            1278.00
# 3            1326.00
# 4            1291.00
# ...              ...
# 3868         1604.50
# 3869         1197.53
# 3870         1604.00
# 3871         1594.00
# 3872         1534.00
#
# [3873 rows x 8 columns]

# %%
# Merge count_and_gdp_df with medal count
count_and_medal_df = pd.merge(count_and_gdp_filter_df, medal_count_df, how='left', left_on=['NOC', 'Year', 'Season'], right_on=['NOC Code', 'Year', 'Season'])
count_and_medal_df = count_and_medal_df.drop(['NOC Code', 'Unnamed: 0'], axis=1)
count_and_medal_df
# Out:
#       NOC  Year  Season  Host  athlete_count  Population  GDP per capita  \
# 0     AFG  1936  Summer     0              4         NaN             NaN
# 1     AFG  1948  Summer     0              2         NaN             NaN
# 2     AFG  1956  Summer     0              1         NaN         1278.00
# 3     AFG  1960  Summer     0             13   8996967.0         1326.00
# 4     AFG  1964  Summer     0              8   9744772.0         1291.00
# ...   ...   ...     ...   ...            ...         ...             ...
# 3868  ZIM  2004  Summer     0             13  12019911.0         1604.50
# 3869  ZIM  2008  Summer     0             16  12379553.0         1197.53
# 3870  ZIM  2012  Summer     0              9  13115149.0         1604.00
# 3871  ZIM  2014  Winter     0              2  13586710.0         1594.00
# 3872  ZIM  2016  Summer     0             15  14030338.0         1534.00
#
#       Gold  Silver  Bronze  Total
# 0      NaN     NaN     NaN    NaN
# 1      NaN     NaN     NaN    NaN
# 2      NaN     NaN     NaN    NaN
# 3      NaN     NaN     NaN    NaN
# 4      NaN     NaN     NaN    NaN
# ...    ...     ...     ...    ...
# 3868   1.0     1.0     1.0    3.0
# 3869   1.0     3.0     0.0    4.0
# 3870   NaN     NaN     NaN    NaN
# 3871   NaN     NaN     NaN    NaN
# 3872   NaN     NaN     NaN    NaN
#
# [3873 rows x 11 columns]

# %%
# Filter out years before 1960 and fill NaN
ML_df = count_and_medal_df[count_and_medal_df['Year'] > 1959]
ML_df[['Gold', 'Silver', 'Bronze', 'Total']] = ML_df[['Gold', 'Silver', 'Bronze', 'Total']].fillna(value=0)
ML_df.head()
# Out:
# C:\Users\benja\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#    NOC  Year  Season  Host  athlete_count  Population  GDP per capita  Gold  \
# 3  AFG  1960  Summer     0             13   8996967.0          1326.0   0.0
# 4  AFG  1964  Summer     0              8   9744772.0          1291.0   0.0
# 5  AFG  1968  Summer     0              5  10637064.0          1290.0   0.0
# 6  AFG  1972  Summer     0              8  11791222.0          1007.0   0.0
# 7  AFG  1980  Summer     0             11  13356500.0          1019.0   0.0
#
#    Silver  Bronze  Total
# 3     0.0     0.0    0.0
# 4     0.0     0.0    0.0
# 5     0.0     0.0    0.0
# 6     0.0     0.0    0.0
# 7     0.0     0.0    0.0

# %%
ML_df = ML_df.dropna()

# %%
ML_df = ML_df.reset_index()

# %%
ML_df.describe()
# Out:
#            level_0        index         Year         Host  athlete_count  \
# count  2503.000000  2503.000000  2503.000000  2503.000000    2503.000000
# mean   1549.974830  1911.259289  1993.105074     0.010787      55.694367
# std     882.637787  1087.664699    16.275940     0.103320      83.199012
# min       0.000000     3.000000  1960.000000     0.000000       1.000000
# 25%     781.500000   936.500000  1980.000000     0.000000       7.000000
# 50%    1545.000000  1931.000000  1996.000000     0.000000      20.000000
# 75%    2285.500000  2810.500000  2008.000000     0.000000      67.000000
# max    3147.000000  3872.000000  2016.000000     1.000000     555.000000
#
#          Population  GDP per capita         Gold       Silver       Bronze  \
# count  2.503000e+03     2503.000000  2503.000000  2503.000000  2503.000000
# mean   4.199663e+07    13538.390635     1.433480     1.463044     1.617259
# std    1.425546e+08    13634.703571     4.585395     3.920591     4.010345
# min    6.326100e+04        0.000000     0.000000     0.000000     0.000000
# 25%    3.783898e+06     3250.320000     0.000000     0.000000     0.000000
# 50%    9.527985e+06     9199.000000     0.000000     0.000000     0.000000
# 75%    2.909393e+07    20032.720000     1.000000     1.000000     1.000000
# max    1.387790e+09   156299.000000    83.000000    61.000000    38.000000
#
#              Total
# count  2503.000000
# mean      4.513783
# std      12.027335
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       3.000000
# max     174.000000

# %%
ML_df.to_csv('CSV_In_Progress/MLR_dataset.csv')

# %%
# Import dependencies
import pandas as pd

# %%
# Read Summer Csv
summer_ml_file = pd.read_csv('summer_ML_final.csv')
summer_ml_file
# Out:
#      Year  season       country  noc  population  gdpperc  athlete_share  \
# 0    2016  summer       Bolivia  BOL    11031800   6355.0       0.001225
# 1    2016  summer       Finland  FIN     5495300  37239.0       0.006430
# 2    2016  summer  South Africa  RSA    56207600  12139.0       0.010308
# 3    2016  summer      Dominica  DMA       71307   9550.0       0.000204
# 4    2016  summer       Ukraine  UKR    45004700   9214.0       0.023576
# ..    ...     ...           ...  ...         ...      ...            ...
# 156  2016  summer        Malawi  MAW    17205300   1112.0       0.000510
# 157  2016  summer         Spain  ESP    46484100  30110.0       0.024087
# 158  2016  summer       Tunisia  TUN    11303900  11073.0       0.005103
# 159  2016  summer         Kenya  KEN    49051500   3169.0       0.005920
# 160  2016  summer    Madagascar  MAD    24894400   1381.0       0.000612
#
#      host  country_medal_total  medal_share_predicted  positive_medal_share  \
# ...

# %%
# Read Summer Csv
winter_ml_file = pd.read_csv('Winter_ML_final.csv')
winter_ml_file
# Out:
#     Unnamed: 0  year  season     Country  noc    population  gdpperc  \
# 0            0  2014  Winter      Canada  CAN  3.543740e+07  43607.0
# 1            1  2014  Winter  Azerbaijan  AZE  9.535080e+06  17439.0
# 2            2  2014  Winter     Iceland  ISL  3.273860e+05  38563.0
# 3            3  2014  Winter    Paraguay  PAR  6.599520e+06   8382.0
# 4            4  2014  Winter     Albania  ALB  2.889100e+06   9808.0
# ..         ...   ...     ...         ...  ...           ...      ...
# 69          69  2014  Winter       India  IND  1.295600e+09   5458.0
# 70          70  2014  Winter     Ireland  IRL  4.657740e+06  52651.0
# 71          71  2014  Winter        Peru  PER  3.009040e+07  11186.0
# 72          72  2014  Winter     Moldova  MDA  2.856950e+06   5739.0
# 73          73  2014  Winter       Nepal  NEP  2.690600e+07   2421.0
#
#     athlete_share  host  country_medal_total  medal_share_predicted  \
# 0        0.068274     0                 25.0               0.084995
# ...

# %%
# Convert Pandas summer Df to JSON
json_output = r"C:\Users\Lenovo\Documents\olympic_medal_analysis\Olympic_map\static\json\summer_ML.json"
output = summer_ml_file.to_json(json_output, indent = 1, orient= 'records')

# %%
# Convert Pandas summer Df to JSON
json_output2 = r"C:\Users\Lenovo\Documents\olympic_medal_analysis\Olympic_map\static\json\Winter_ML.json"
output2 = winter_ml_file.to_json(json_output2, indent = 1, orient= 'records')

# %%
# Import dependencies
import pandas as pd
import numpy as np

# %%
# Read Csv. Skip first 3 rows to avoid parser error
pop_file = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_3469297.csv')
pop_file
# Out:
#                     Country Name Country Code  REC     Indicator Name  \
# 0                          Aruba          ARU  ARU  Population, total
# 1    Africa Eastern and Southern          AFE  NaN  Population, total
# 2                    Afghanistan          AFG  AFG  Population, total
# 3     Africa Western and Central          AFW  NaN  Population, total
# 4                         Angola          ANG  ANG  Population, total
# ..                           ...          ...  ...                ...
# 261                       Kosovo          KOS  KOS  Population, total
# 262                        Yemen          YEM  YEM  Population, total
# 263                 South Africa          RSA  RSA  Population, total
# 264                       Zambia          ZAM  ZAM  Population, total
# 265                     Zimbabwe          ZIM  ZIM  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# ...

# %%
# Drop NaN values
pop_file.dropna(inplace=True)

# %%
# Drop columns not needed and use melt() funt to keep cols need & name them
temp = pop_file.drop(columns=['Indicator Name', 'Indicator Code', 'REC'])
clean_pop =temp.melt(id_vars=['Country Code', 'Country Name'], var_name = 'Year', value_name = 'Population') 
clean_pop
# Out:
#       Country Code  Country Name  Year  Population
# 0              ARU         Aruba  1960     54208.0
# 1              AFG   Afghanistan  1960   8996967.0
# 2              ANG        Angola  1960   5454938.0
# 3              ALB       Albania  1960   1608800.0
# 4              AND       Andorra  1960     13410.0
# ...            ...           ...   ...         ...
# 12134          KOS        Kosovo  2020   1775378.0
# 12135          YEM         Yemen  2020  29825968.0
# 12136          RSA  South Africa  2020  59308690.0
# 12137          ZAM        Zambia  2020  18383956.0
# 12138          ZIM      Zimbabwe  2020  14862927.0
#
# [12139 rows x 4 columns]

# %%
# Sum of NA values
clean_pop.isna().sum()
# Out:
# Country Code    0
# Country Name    0
# Year            0
# Population      0
# dtype: int64

# %%
# View the columns
clean_pop.columns
# Out:
# Index(['Country Code', 'Country Name', 'Year', 'Population'], dtype='object')

# %%
clean_pop.describe()
# Out:
#          Population
# count  1.213900e+04
# mean   2.649690e+07
# std    1.067971e+08
# min    4.377000e+03
# 25%    8.220545e+05
# 50%    4.894580e+06
# 75%    1.542205e+07
# max    1.410929e+09

# %%
# Check Value types
clean_pop.dtypes
# Out:
# Country Code     object
# Country Name     object
# Year             object
# Population      float64
# dtype: object

# %%
#View data matches with excel files
clean_pop.loc[clean_pop['Country Name'] == 'Angola']
# Out:
#       Country Code Country Name  Year  Population
# 2              ANG       Angola  1960   5454938.0
# 201            ANG       Angola  1961   5531451.0
# 400            ANG       Angola  1962   5608499.0
# 599            ANG       Angola  1963   5679409.0
# 798            ANG       Angola  1964   5734995.0
# ...            ...          ...   ...         ...
# 11146          ANG       Angola  2016  28842482.0
# 11345          ANG       Angola  2017  29816769.0
# 11544          ANG       Angola  2018  30809787.0
# 11743          ANG       Angola  2019  31825299.0
# 11942          ANG       Angola  2020  32866268.0
#
# [61 rows x 4 columns]

# %%
# View if Not Classified (INX) aka Indonesia dropped
clean_pop.loc[clean_pop['Country Name'] == 'Not classified']
# Out:
# Empty DataFrame
# Columns: [Country Code, Country Name, Year, Population]
# Index: []

# %%
# Check to ee if Nulls were dropped
clean_pop.loc[clean_pop['Country Name'] == 'Africa East and Southern Bank']
# Out:
# Empty DataFrame
# Columns: [Country Code, Country Name, Year, Population]
# Index: []

# %%
clean_pop.loc[clean_pop['Country Name'] == 'Bermuda']
# Out:
#       Country Code Country Name  Year  Population
# 24             BER      Bermuda  1960     44400.0
# 223            BER      Bermuda  1961     45500.0
# 422            BER      Bermuda  1962     46600.0
# 621            BER      Bermuda  1963     47700.0
# 820            BER      Bermuda  1964     48900.0
# ...            ...          ...   ...         ...
# 11168          BER      Bermuda  2016     64554.0
# 11367          BER      Bermuda  2017     63873.0
# 11566          BER      Bermuda  2018     63919.0
# 11765          BER      Bermuda  2019     63913.0
# 11964          BER      Bermuda  2020     63903.0
#
# [61 rows x 4 columns]

# %%
clean_pop.loc[clean_pop['Country Name'] == 'Greenland']
# Out:
# Empty DataFrame
# Columns: [Country Code, Country Name, Year, Population]
# Index: []

# %%
# Export clean Population df as a CSV
clean_pop.to_csv('Clean_Country_population.csv', index=False)
